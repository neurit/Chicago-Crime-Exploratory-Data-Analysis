# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ### Imports and Initial Checks

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import geopandas as gpd
import gmaps
from sodapy import Socrata
import requests
import json
import dateutil
import pytz
import datetime

# %matplotlib inline

# %%
df = pd.read_csv("Crimes_-_2001_to_present.csv", index_col = "ID")
df.head()
# Out:
# /Users/ashwin/anaconda3/lib/python3.6/site-packages/numpy/lib/arraysetops.py:466: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)
#          Case Number                    Date                   Block  IUCR  \
# ID
# 10000092    HY189866  03/18/2015 07:44:00 PM         047XX W OHIO ST  041A
# 10000094    HY190059  03/18/2015 11:00:00 PM  066XX S MARSHFIELD AVE  4625
# 10000095    HY190052  03/18/2015 10:45:00 PM   044XX S LAKE PARK AVE  0486
# 10000096    HY190054  03/18/2015 10:30:00 PM    051XX S MICHIGAN AVE  0460
# 10000097    HY189976  03/18/2015 09:00:00 PM        047XX W ADAMS ST  031A
#
#            Primary Type              Description Location Description  Arrest  \
# ID
# 10000092        BATTERY      AGGRAVATED: HANDGUN               STREET   False
# 10000094  OTHER OFFENSE         PAROLE VIOLATION               STREET    True
# 10000095        BATTERY  DOMESTIC BATTERY SIMPLE            APARTMENT   False
# 10000096        BATTERY                   SIMPLE            APARTMENT   False
# 10000097        ROBBERY           ARMED: HANDGUN             SIDEWALK   False
#
#           Domestic  Beat              ...                Ward  Community Area  \
# ID                                    ...
# 10000092     False  1111              ...                28.0            25.0
# 10000094     False   725              ...                15.0            67.0
# 10000095      True   222              ...                 4.0            39.0
# 10000096     False   225              ...                 3.0            40.0
# 10000097     False  1113              ...                28.0            25.0
#
#           FBI Code X Coordinate  Y Coordinate  Year              Updated On  \
# ID
# 10000092       04B    1144606.0     1903566.0  2015  02/10/2018 03:50:01 PM
# 10000094        26    1166468.0     1860715.0  2015  02/10/2018 03:50:01 PM
# 10000095       08B    1185075.0     1875622.0  2015  02/10/2018 03:50:01 PM
# 10000096       08B    1178033.0     1870804.0  2015  02/10/2018 03:50:01 PM
# 10000097        03    1144920.0     1898709.0  2015  02/10/2018 03:50:01 PM
#
#            Latitude  Longitude                       Location
# ID
# 10000092  41.891399 -87.744385  (41.891398861, -87.744384567)
# 10000094  41.773372 -87.665319  (41.773371528, -87.665319468)
# 10000095  41.813861 -87.596643   (41.81386068, -87.596642837)
# 10000096  41.800802 -87.622619  (41.800802415, -87.622619343)
# 10000097  41.878065 -87.743354  (41.878064761, -87.743354013)
#
# [5 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6583286 entries, 10000092 to 9780607
# Data columns (total 21 columns):
# Case Number             object
# Date                    object
# Block                   object
# IUCR                    object
# Primary Type            object
# Description             object
# Location Description    object
# Arrest                  bool
# Domestic                bool
# Beat                    int64
# District                float64
# Ward                    float64
# Community Area          float64
# FBI Code                object
# X Coordinate            float64
# Y Coordinate            float64
# Year                    int64
# Updated On              object
# Latitude                float64
# Longitude               float64
# Location                object
# dtypes: bool(2), float64(7), int64(2), object(10)
# memory usage: 1017.1+ MB

# %%
df.isnull().sum()
# Out:
# Case Number                  4
# Date                         0
# Block                        0
# IUCR                         0
# Primary Type                 0
# Description                  0
# Location Description      3398
# Arrest                       0
# Domestic                     0
# Beat                         0
# District                    51
# Ward                    614854
# Community Area          616029
# FBI Code                     0
# X Coordinate             67651
# Y Coordinate             67651
# Year                         0
# Updated On                   0
# Latitude                 67651
# Longitude                67651
# Location                 67651
# dtype: int64

# %% [markdown]
# ### Typos and Redundancies

# %% [markdown]
# We first look at just the primary type and description fields, using value counts to detect possible typos.

# %% [markdown]
# #### Primary Type

# %%
df["Primary Type"].value_counts()
# Out:
# THEFT                                1377760
# BATTERY                              1201381
# CRIMINAL DAMAGE                       754293
# NARCOTICS                             703168
# OTHER OFFENSE                         408322
# ASSAULT                               405870
# BURGLARY                              380748
# MOTOR VEHICLE THEFT                   308451
# DECEPTIVE PRACTICE                    250560
# ROBBERY                               249926
# CRIMINAL TRESPASS                     189367
# PROSTITUTION                           67828
# WEAPONS VIOLATION                      67228
# PUBLIC PEACE VIOLATION                 46948
# OFFENSE INVOLVING CHILDREN             43884
# CRIM SEXUAL ASSAULT                    25980
# SEX OFFENSE                            24288
# INTERFERENCE WITH PUBLIC OFFICER       14337
# GAMBLING                               14245
# LIQUOR LAW VIOLATION                   13875
# ARSON                                  10917
# HOMICIDE                                9041
# KIDNAPPING                              6571
# INTIMIDATION                            3823
# STALKING                                3234
# OBSCENITY                                533
# CONCEALED CARRY LICENSE VIOLATION        182
# PUBLIC INDECENCY                         151
# NON-CRIMINAL                             143
# OTHER NARCOTIC VIOLATION                 123
# HUMAN TRAFFICKING                         40
# NON - CRIMINAL                            38
# RITUALISM                                 23
# NON-CRIMINAL (SUBJECT SPECIFIED)           7
# DOMESTIC VIOLENCE                          1
# Name: Primary Type, dtype: int64

# %% [markdown]
# The single "DOMESTIC VIOLENCE" case seems like an error, and "NON-CRIMINAL" has a low incidence number and is redundant to "NON-CRIMINAL".

# %%
df.loc[df["Primary Type"] == "NON - CRIMINAL", "Primary Type"] = "NON-CRIMINAL"

# %%
df[df["Primary Type"] == "DOMESTIC VIOLENCE"]
# Out:
#         Case Number                    Date                Block  IUCR  \
# ID
# 1326195     G021609  01/11/2001 02:30:41 AM  087XX S ESCANABA AV  9901
#
#               Primary Type        Description Location Description  Arrest  \
# ID
# 1326195  DOMESTIC VIOLENCE  DOMESTIC VIOLENCE            APARTMENT    True
#
#          Domestic  Beat              ...               Ward  Community Area  \
# ID                                   ...
# 1326195      True   423              ...                NaN             NaN
#
#          FBI Code X Coordinate  Y Coordinate  Year              Updated On  \
# ID
# 1326195       08B    1196869.0     1847416.0  2001  08/17/2015 03:03:40 PM
#
#           Latitude  Longitude                      Location
# ID
# 1326195  41.736176  -87.55432  (41.73617608, -87.554319607)
#
# [1 rows x 21 columns]

# %%
df[df["FBI Code"] == "08B"]
# Out:
#          Case Number                    Date                     Block  IUCR  \
# ID
# 10000095    HY190052  03/18/2015 10:45:00 PM     044XX S LAKE PARK AVE  0486
# 10000096    HY190054  03/18/2015 10:30:00 PM      051XX S MICHIGAN AVE  0460
# 10000098    HY190032  03/18/2015 10:00:00 PM       049XX S DREXEL BLVD  0460
# 10000099    HY190047  03/18/2015 11:00:00 PM         070XX S MORGAN ST  0486
# 10000100    HY189988  03/18/2015 09:35:00 PM       042XX S PRAIRIE AVE  0486
# 10000104    HY189964  03/18/2015 09:25:00 PM       097XX S PRAIRIE AVE  0460
# 10000110    HY190056  03/18/2015 10:50:00 PM       014XX S ASHLAND AVE  0460
ATTERY     DOMESTIC BATTERY SIMPLE                  APARTMENT
# 9882759       BATTERY     DOMESTIC BATTERY SIMPLE                  RESIDENCE
# 9883446       BATTERY     DOMESTIC BATTERY SIMPLE                   SIDEWALK
# 9884270       BATTERY                      SIMPLE                     STREET
# 9886777       BATTERY     DOMESTIC BATTERY SIMPLE                  RESIDENCE
# 9887034       BATTERY     DOMESTIC BATTERY SIMPLE                  APARTMENT
# 9910796       BATTERY     DOMESTIC BATTERY SIMPLE                  APARTMENT
# 9911005       BATTERY     DOMESTIC BATTERY SIMPLE                  APARTMENT
# 9922355       BATTERY     DOMESTIC BATTERY SIMPLE                  APARTMENT
# 9931004       BATTERY                      SIMPLE                     STREET
# 9931264       BATTERY     DOMESTIC BATTERY SIMPLE                  RESIDENCE
# 9932151       BATTERY     DOMESTIC BATTERY SIMPLE                  RESIDENCE
# 9938886       BATTERY     DOMESTIC BATTERY SIMPLE                  APARTMENT
# 9942388       BATTERY                      SIMPLE                   SIDEWALK
# 9955607       BATTERY                      SIMPLE              BAR OR TAVERN
# 9965334       BATTERY     DOMESTIC BATTERY SIMPLE                  APARTMENT
# 9980258       BATTERY                      SIMPLE                  CTA TRAIN
# 9981103       BATTERY     DOMESTIC BATTERY SIMPLE                  APARTMENT
# 11220769      BATTERY                      SIMPLE                  CTA TRAIN
# 11220776      BATTERY     DOMESTIC BATTERY SIMPLE                  APARTMENT
# 11220800      BATTERY                      SIMPLE                     STREET
# 11220804      BATTERY     DOMESTIC BATTERY SIMPLE                  RESIDENCE
# 11220805      BATTERY     DOMESTIC BATTERY SIMPLE                  RESIDENCE
# 11220814      BATTERY  AGG PO HANDS NO/MIN INJURY                  APARTMENT
# 11220815      BATTERY     DOMESTIC BATTERY SIMPLE                  RESIDENCE
# 11221128      BATTERY  AGG PO HANDS NO/MIN INJURY                     STREET
# 11222440      BATTERY                      SIMPLE                  RESIDENCE
#
#           Arrest  Domestic  Beat              ...                Ward  \
# ID                                            ...
# 10000095   False      True   222              ...                 4.0
# 10000096   False     False   225              ...                 3.0
# 10000098   False     False   223              ...                 4.0
# 10000099   False      True   733              ...                17.0
# 10000100   False      True   213              ...                 3.0
# 10000104   False     False   511              ...                 6.0
# 10000110   False     False  1233              ...                 2.0
# 10000124    True      True  1034              ...                25.0
# 10000126    True      True   232              ...                20.0
# 10000129   False     False   621              ...                17.0
# 10000143   False      True   321              ...                 5.0
# 10000147    True      True   421              ...                 7.0
# 10000149   False     False  1434              ...                32.0
# 10000155   False      True   312              ...                20.0
# 10000166   False      True   332              ...                 5.0
# 10000170   False      True  1512              ...                29.0
# 10000179    True     False  1531              ...                37.0
# 10000188   False      True   732              ...                 6.0
# 10000194   False      True  1412              ...                35.0
# 10000207   False      True   414              ...                 7.0
# 10000208   False      True   815              ...                14.0
# 10000212   False      True   612              ...                21.0
# 10000233   False     False  1115              ...                28.0
# 10000324    True      True  2413              ...                50.0
# 10000337   False     False   411              ...                 8.0
# 10000372   False     False   932              ...                16.0
# 10000399   False      True   312              ...                20.0
# 10000433   False      True   322              ...                 6.0
# 10000477   False     False   211              ...                 4.0
# 10000561   False      True  1112              ...                27.0
# ...          ...       ...   ...              ...                 ...
# 9876136    False      True  1422              ...                26.0
# 9877040    False     False  1921              ...                47.0
# 9877635    False     False   524              ...                34.0
# 9878171    False      True  1024              ...                22.0
# 9882759    False      True  1824              ...                42.0
# 9883446    False      True  1533              ...                29.0
# 9884270    False     False  1924              ...                44.0
# 10000179  (41.894945606, -87.754874977)
# 10000188  (41.767160003, -87.635120381)
# 10000194  (41.931993727, -87.710468903)
# 10000207  (41.754706432, -87.567505523)
# 10000208  (41.805166896, -87.727180679)
# 10000212  (41.748560656, -87.661615335)
# 10000233   (41.88065283, -87.731763004)
# 10000324  (41.993281593, -87.709220588)
# 10000337  (41.757630995, -87.585708249)
# 10000372  (41.801012898, -87.674502123)
# 10000399  (41.779678598, -87.613195473)
# 10000433  (41.768957248, -87.618564735)
# 10000477  (41.833139425, -87.615319213)
# 10000561  (41.897793069, -87.724931802)
# ...                                 ...
# 9876136   (41.914515909, -87.715069795)
# 9877040   (41.949472932, -87.688334239)
# 9877635   (41.677192782, -87.641888286)
# 9878171   (41.849110387, -87.713703339)
# 9882759   (41.910273471, -87.628856792)
# 9883446   (41.875600327, -87.749240606)
# 9884270   (41.943571065, -87.653768342)
# 9886777   (41.940376874, -87.687051261)
# 9887034   (41.929723607, -87.678779951)
# 9910796   (41.765046486, -87.654746497)
# 9911005   (41.768955965, -87.576375769)
# 9922355   (41.995077919, -87.685247371)
# 9931004   (41.817451867, -87.623051594)
# 9931264   (41.722815165, -87.612958946)
# 9932151   (41.671654586, -87.640501773)
# 9938886                             NaN
# 9942388   (41.967166718, -87.661857257)
# 9955607   (41.965261455, -87.708376337)
# 9965334    (41.93785833, -87.688142558)
# 9980258   (41.852419423, -87.627080475)
# 9981103   (41.894949667, -87.752417738)
# 11220769   (41.875282737, -87.68640032)
# 11220776  (41.749889216, -87.598023367)
# 11220800  (41.779086462, -87.682279227)
# 11220804  (41.786774078, -87.798929255)
# 11220805  (41.776116009, -87.672469315)
# 11220814  (41.948130027, -87.643324221)
# 11220815  (41.745329226, -87.664672148)
# 11221128  (41.880083028, -87.768155147)
# 11222440  (41.899458076, -87.721176676)
#
# [1027563 rows x 21 columns]

# %% [markdown]
# So going off the FBI Code, the actual crime for the entry is most likely simple domestic battery.

# %%
df.loc[df["Primary Type"] == "DOMESTIC VIOLENCE", ["Primary Type", "Description"]] = ("BATTERY", "SIMPLE DOMESTIC BATTERY")

# %% [markdown]
# #### Description

# %%
df.groupby("Primary Type")["Description"].value_counts()
# Out:
# Primary Type       Description
# ARSON              BY FIRE                                              7095
#                    AGGRAVATED                                           1819
#                    ATTEMPT ARSON                                        1789
#                    BY EXPLOSIVE                                           95
#                    POS: EXPLOSIVE/INCENDIARY DEV                          79
#                    POS: CHEMICAL/DRY-ICE DEVICE                           40
# ASSAULT            SIMPLE                                             282173
#                    AGGRAVATED: HANDGUN                                 44157
#                    AGGRAVATED:KNIFE/CUTTING INSTR                      28696
#                    AGGRAVATED: OTHER DANG WEAPON                       24290
#                    PRO EMP HANDS NO/MIN INJURY                         13894
#                    AGG PO HANDS NO/MIN INJURY                           6135
#                    AGGRAVATED: OTHER FIREARM                            1905
#                    AGGRAVATED PO: OTHER DANG WEAP                       1176
#                    AGG PRO.EMP: OTHER DANG WEAPON                       1048
#                    AGGRAVATED PO: HANDGUN                                934
#                    AGGRAVATED PO:KNIFE/CUT INSTR                         516
#                    AGG PRO.EMP:KNIFE/CUTTING INST                        459
#                    AGG PRO.EMP: HANDGUN                                  329
#                    AGG PRO.EMP: OTHER FIREARM                             79
#                    AGGRAVATED PO: OTHER FIREARM                           79
# BATTERY            DOMESTIC BATTERY SIMPLE                            502513
#                    SIMPLE                                             492820
#                    AGGRAVATED: OTHER DANG WEAPON                       66779
#                    AGGRAVATED: HANDGUN                                 35182
#                    AGGRAVATED:KNIFE/CUTTING INSTR                      26348
#                    AGGRAVATED DOMESTIC BATTERY: OTHER DANG WEAPON      17483
#                    PRO EMP HANDS NO/MIN INJURY                         14642
#                    AGG PO HANDS NO/MIN INJURY                          12703
#                    AGGRAVATED DOMESTIC BATTERY: KNIFE/CUTTING INST     12059
#                                                                        ...
# THEFT              OVER $500                                          338807
#                    FROM BUILDING                                      220337
#                    RETAIL THEFT                                       160945
#                    FINANCIAL ID THEFT: OVER $300                       44531
#                    POCKET-PICKING                                      31567
#                    PURSE-SNATCHING                                     16312
#                    FINANCIAL ID THEFT:$300 &UNDER                      15206
#                    ATTEMPT THEFT                                       10918
#                    ATTEMPT FINANCIAL IDENTITY THEFT                     2955
#                    AGG: FINANCIAL ID THEFT                              2901
#                    FROM COIN-OP MACHINE/DEVICE                          1081
#                    DELIVERY CONTAINER THEFT                              868
#                    $300 AND UNDER                                         15
#                    OVER $300                                              13
#                    THEFT RETAIL                                            1
# WEAPONS VIOLATION  UNLAWFUL POSS OF HANDGUN                            44740
#                    UNLAWFUL USE OTHER DANG WEAPON                       8398
#                    UNLAWFUL USE HANDGUN                                 2829
#                    UNLAWFUL POSS OTHER FIREARM                          2655
#                    UNLAWFUL USE/SALE AIR RIFLE                          2392
#                    POSS FIREARM/AMMO:NO FOID CARD                       1956
#                    RECKLESS FIREARM DISCHARGE                           1865
#                    UNLAWFUL POSS AMMUNITION                             1428
#                    UNLAWFUL USE OTHER FIREARM                            471
#                    UNLAWFUL SALE HANDGUN                                 218
#                    UNLAWFUL SALE/DELIVERY OF FIREARM AT SCHOOL           150
#                    UNLAWFUL SALE OTHER FIREARM                            82
#                    DEFACE IDENT MARKS OF FIREARM                          35
#                    REGISTER OF SALES BY DEALER                             5
#                    USE OF METAL PIERCING BULLETS                           4
# Name: Description, Length: 404, dtype: int64

# %% [markdown]
# There are a few backwards phrases, but otherwise, nothing immediately stands out and most of the low frequency counts are just clearly uncommon crimes. A strategy for automatically detecting probable typos in the future is to group attributes by frequency, and compare the Levenshtein distance between high frequency and low frequency groups; attributes below a certain distance threshold, or attributes that "fuzzily match" and are not common are more likely to be typos.

# %%
df.loc[df["Description"] == "THEFT RETAIL", "Description"] = "RETAIL THEFT"
df.loc[df["Description"] == "SIMPLE DOMESTIC BATTERY", "Description"] = "DOMESTIC BATTERY SIMPLE"

# %% [markdown]
# ### Missing Values

# %% [markdown]
# The general approach here is to first impute matching values, then geocode still missing location coordinates, and finally use those coordinates and Chicago shapefiles to fill in the rest of missing fields.
#
# We assume that fields that have the same block field, also have the same location fields (and by extension, the same community areas, wards, etc.). This is justified by the dataset description:
# >In order to protect the privacy of crime victims, addresses are shown at the block level only and specific locations are not identified. The intent is to not make crimes exactly traceable.
#
# In other words, that blocks are the lowest level of geogrphical specificity given. Since the block field is not an actual address, there's an issue that the block may cross a given community area or ward boundary, and thus make those fields ambigiuous; in practice, however, those values are infrequent enough to not affect distributions (as shown later in the validation section, where we compare matching imputed values with already present values).

# %% [markdown]
# #### Internal Imputation

# %%
# get counts of missing values again
df.isnull().sum()
# Out:
# Case Number                  4
# Date                         0
# Block                        0
# IUCR                         0
# Primary Type                 0
# Description                  0
# Location Description      3398
# Arrest                       0
# Domestic                     0
# Beat                         0
# District                    51
# Ward                    614854
# Community Area          616029
# FBI Code                     0
# X Coordinate             67651
# Y Coordinate             67651
# Year                         0
# Updated On                   0
# Latitude                 67651
# Longitude                67651
# Location                 67651
# dtype: int64

# %% [markdown]
# Then let's see how many missing values belong to unique blocks, ignoring the ward field for now as ward boundaries switched and thus require an extra conditional on the year field.

# %%
# list of missing field values (ignoring location and X-Y coorindates, since they're redundant
missing_fields = ["Community Area", "Ward", "Latitude", "Longitude"]

for field in missing_fields:
    print("{} has {} unique missing values.".format(field, df.loc[df[field].isnull(), "Block"].unique().shape[0]))
# Out:
# Community Area has 31321 unique missing values.
# Ward has 31222 unique missing values.
# Latitude has 22409 unique missing values.
# Longitude has 22409 unique missing values.

# %% [markdown]
# So we just have to impute these missing values by matching on block.

# %%
for field in missing_fields:
    # rows that have this missing field filled in as a reference
    known_field = df[df[field].notnull()]
    
    # dictionary mapping known block to this field
    block_to_field = pd.Series(known_field[field].values, index = known_field.Block).to_dict()
    
    # convert known blocks to set for faster lookup
    known_blocks = set(known_field.Block)
    
    # use known block to field relation to impute
    df.loc[df[field].isnull() & df["Block"].isin(known_blocks), field] = \
        df.loc[df[field].isnull() & df["Block"].isin(known_blocks), "Block"].map(block_to_field)

# %%
df.isnull().sum()
# Out:
# Case Number                  4
# Date                         0
# Block                        0
# IUCR                         0
# Primary Type                 0
# Description                  0
# Location Description      3398
# Arrest                       0
# Domestic                     0
# Beat                         0
# District                    51
# Ward                    438000
# Community Area          438399
# FBI Code                     0
# X Coordinate             67651
# Y Coordinate             67651
# Year                         0
# Updated On                   0
# Latitude                  2472
# Longitude                 2472
# Location                 67651
# dtype: int64

# %%
# list of missing field values (ignoring location and X-Y coorindates, since they're redundant
missing_fields = ["Community Area", "Ward", "Latitude", "Longitude"]

for field in missing_fields:
    print("{} has {} unique missing values.".format(field, df.loc[df[field].isnull(), "Block"].unique().shape[0]))
# Out:
# Community Area has 24233 unique missing values.
# Ward has 24185 unique missing values.
# Latitude has 1189 unique missing values.
# Longitude has 1189 unique missing values.

# %% [markdown]
# So we're now well within the limit of most free geocoders.

# %% [markdown]
# #### Fuzzy Match Blocks

# %% [markdown]
# We fuzzy match block names with the official Chicago street name open dataset, looking only at values that are missing their longitude and latitude so as to improve the accuracy/consistency of future geocoding.

# %%
from sodapy import Socrata

# load soda authentication token
with open("app_token") as f:
    app_token = f.read().rstrip("\n")
    
# open soda client object for Chicago city data
client = Socrata("data.cityofchicago.org", app_token)

# get street names
street_names = client.get("pasq-g8mx", limit = 5000000)

# %%
from fuzzywuzzy import process
from fuzzywuzzy import fuzz

# %%
street_names = pd.DataFrame(street_names)

# drop block number, get only unique street names
missing_streets = pd.Series(df[df.Latitude.isnull()].Block.apply(lambda x: " ".join(x.split()[1:]).upper()).unique())

# %%
# look only at missing streets that are not already a perfect match with an official Chicago street
imperfect_streets = missing_streets[~missing_streets.isin(street_names["full_street_name"])]

street_matches = [process.extractOne(street, street_names["full_street_name"].values) for street in imperfect_streets]

# use another scorer that works better with highways
street_matches_set = [process.extractOne(street, street_names["full_street_name"].values, scorer = fuzz.token_set_ratio) 
                       for street in imperfect_streets]

# %%
matches = [(x[0][0], x[1][0]) for x in zip(street_matches, street_matches_set)]

# %%
# store matches in dataframe for ease of use
imperfect_matches = pd.DataFrame(dict(zip(imperfect_streets, matches))).transpose()
imperfect_matches = imperfect_matches.rename(columns = {0: "Candidate", 1: "Alt Candidate"})
imperfect_matches.index = imperfect_matches.index.rename("Street")

# %% [markdown]
# We now export these matches to a csv to be manually checked in Excel. The candidate column is edited to be correct; the edited version can then be imported to construct a dictionary mapping streets to their proper official names.

# %%
imperfect_matches.to_csv("fuzzy_matches.csv")

# %%
# reimport externally edited csv
matched = pd.read_csv("fuzzy_matches_edited.csv", index_col = "Street")

# create mapping dictionary
matched_streets = matched.Candidate.to_dict()

# %%
def apply_matching(row):
    ''' helper function for mapping substring '''
    street = " ".join(row.Block.split()[1:]).upper()
    
    if street in matched_streets:
        return row.Block.replace(street, matched_streets[street])
    else:
        return row.Block

# %%
df.loc[df["Latitude"].isnull(), "Block"] = df[df["Latitude"].isnull()].apply(apply_matching, axis = 1)

# %%
# for formatting consistency, make everything upper case
df.Block = df.Block.str.upper()

# %% [markdown]
# #### Geocoding

# %%
# unique blocks we'll need to geocode
blocks_to_geocode = df[df["Latitude"].isnull()].Block.unique()

# %% [markdown]
# We use both Google Maps and ArcGIS to geocode, for some level of validation.

# %%
# load Google maps api key from file
f = open("api_key")
gmaps_key = f.read().split("\n")[0]
f.close()

# load arcgis password from file
f = open("arc_pass")
arc_pass = f.read().split("\n")[0]
f.close()

# %%
import googlemaps

gmaps = googlemaps.Client(key = gmaps_key)

from arcgis.geocoding import get_geocoders, geocode

gis = GIS("http://www.arcgis.com", "neurite", arc_pass)

# use the first of GIS's configured geocoders
geocoder = get_geocoders(gis)[0]

# %%
arc_geocoded = [geocode(block + "Chicago, IL") for block in blocks_to_geocode]
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-188-038c4f35519e> in <module>()
# ----> 1 arc_geocoded = [geocode(block + "Chicago, IL") for block in blocks_to_geocode]
#
# <ipython-input-188-038c4f35519e> in <listcomp>(.0)
# ----> 1 arc_geocoded = [geocode(block + "Chicago, IL") for block in blocks_to_geocode]
#
# ~/anaconda3/lib/python3.6/site-packages/arcgis/geocoding/_functions.py in geocode(address, search_extent, location, distance, out_sr, category, out_fields, max_locations, magic_key, for_storage, geocoder, as_featureset)
#    1000         magic_key,
#    1001         for_storage,
# -> 1002         as_featureset)
#    1003
#    1004
#
# ~/anaconda3/lib/python3.6/site-packages/arcgis/geocoding/_functions.py in _geocode(self, address, search_extent, location, distance, out_sr, category, out_fields, max_locations, magic_key, for_storage, as_featureset)
#     189             params['forStorage'] = for_storage
#     190
# --> 191         resp = self._con.post(url, params, token=self._token)
#     192
#     193         if resp is not None and as_featureset:
#
# ~/anaconda3/lib/python3.6/site-packages/arcgis/_impl/connection.py in post(self, path, postdata, files, ssl, compress, is_retry, use_ordered_dict, add_token, verify_cert, token, try_json, out_folder, file_name, force_bytes, add_headers)
#    1102             opener.addheaders = headers
#    1103             #print("***"+url)
# -> 1104             resp = opener.open(url, data=encoded_postdata.encode())
#    1105             resp_data, is_file = self._process_response(resp,
#    1106                                                out_folder=out_folder,
#
# ~/anaconda3/lib/python3.6/urllib/request.py in open(self, fullurl, data, timeout)
#     524             req = meth(req)
#     525
# --> 526         response = self._open(req, data)
#     527
#     528         # post-process response
#
# ~/anaconda3/lib/python3.6/urllib/request.py in _open(self, req, data)
#     542         protocol = req.type
#     543         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 544                                   '_open', req)
#     545         if result:
#     546             return result
#
# ~/anaconda3/lib/python3.6/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     502         for handler in handlers:
#     503             func = getattr(handler, meth_name)
# --> 504             result = func(*args)
#     505             if result is not None:
#     506                 return result
#
# ~/anaconda3/lib/python3.6/urllib/request.py in https_open(self, req)
#    1359         def https_open(self, req):
#    1360             return self.do_open(http.client.HTTPSConnection, req,
# -> 1361                 context=self._context, check_hostname=self._check_hostname)
#    1362
#    1363         https_request = AbstractHTTPHandler.do_request_
#
# ~/anaconda3/lib/python3.6/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1319             except OSError as err: # timeout error
#    1320                 raise URLError(err)
# -> 1321             r = h.getresponse()
#    1322         except:
#    1323             h.close()
#
# ~/anaconda3/lib/python3.6/http/client.py in getresponse(self)
#    1329         try:
#    1330             try:
# -> 1331                 response.begin()
#    1332             except ConnectionError:
#    1333                 self.close()
#
# ~/anaconda3/lib/python3.6/http/client.py in begin(self)
#     295         # read until we get a non-100 response
#     296         while True:
# --> 297             version, status, reason = self._read_status()
#     298             if status != CONTINUE:
#     299                 break
#
# ~/anaconda3/lib/python3.6/http/client.py in _read_status(self)
#     256
#     257     def _read_status(self):
# --> 258         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     259         if len(line) > _MAXLINE:
#     260             raise LineTooLong("status line")
#
# ~/anaconda3/lib/python3.6/socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# ~/anaconda3/lib/python3.6/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1007                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1008                   self.__class__)
# -> 1009             return self.read(nbytes, buffer)
#    1010         else:
#    1011             return socket.recv_into(self, buffer, nbytes, flags)
#
# ~/anaconda3/lib/python3.6/ssl.py in read(self, len, buffer)
#     869             raise ValueError("Read on closed or unwrapped SSL socket.")
#     870         try:
# --> 871             return self._sslobj.read(len, buffer)
#     872         except SSLError as x:
#     873             if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# ~/anaconda3/lib/python3.6/ssl.py in read(self, len, buffer)
#     629         """
#     630         if buffer is not None:
# --> 631             v = self._sslobj.read(len, buffer)
#     632         else:
#     633             v = self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
gmaps_geocoded = [gmaps.geocode(block + "Chicago, IL") for block in blocks_to_geocode]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     379             try:  # Python 2.7, use buffering of HTTP responses
# --> 380                 httplib_response = conn.getresponse(buffering=True)
#     381             except TypeError:  # Python 2.6 and older, Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-192-7c203e69374f> in <module>()
# ----> 1 gmaps_geocoded = [gmaps.geocode(block + "Chicago, IL") for block in blocks_to_geocode]
#
# <ipython-input-192-7c203e69374f> in <listcomp>(.0)
# ----> 1 gmaps_geocoded = [gmaps.geocode(block + "Chicago, IL") for block in blocks_to_geocode]
#
# ~/anaconda3/lib/python3.6/site-packages/googlemaps/client.py in wrapper(*args, **kwargs)
#     354     def wrapper(*args, **kwargs):
#     355         args[0]._extra_params = kwargs.pop("extra_params", None)
# --> 356         result = func(*args, **kwargs)
#     357         try:
#     358             del args[0]._extra_params
#
# ~/anaconda3/lib/python3.6/site-packages/googlemaps/geocoding.py in geocode(client, address, components, bounds, region, language)
#      66         params["language"] = language
#      67
# ---> 68     return client._request("/maps/api/geocode/json", params)["results"]
#      69
#      70
#
# ~/anaconda3/lib/python3.6/site-packages/googlemaps/client.py in _request(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs, post_json)
#     227         try:
#     228             response = requests_method(base_url + authed_url,
# --> 229                                        **final_requests_kwargs)
#     230         except requests.exceptions.Timeout:
#     231             raise googlemaps.exceptions.Timeout()
#
# ~/anaconda3/lib/python3.6/site-packages/requests/sessions.py in get(self, url, **kwargs)
#     519
#     520         kwargs.setdefault('allow_redirects', True)
# --> 521         return self.request('GET', url, **kwargs)
#     522
#     523     def options(self, url, **kwargs):
#
# ~/anaconda3/lib/python3.6/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     506         }
#     507         send_kwargs.update(settings)
# --> 508         resp = self.send(prep, **send_kwargs)
#     509
#     510         return resp
#
# ~/anaconda3/lib/python3.6/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     616
#     617         # Send the request
# --> 618         r = adapter.send(request, **kwargs)
#     619
#     620         # Total elapsed time of the request (approximately)
#
# ~/anaconda3/lib/python3.6/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438                     decode_content=False,
#     439                     retries=self.max_retries,
# --> 440                     timeout=timeout
#     441                 )
#     442
#
# ~/anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   timeout=timeout_obj,
#     600                                                   body=body, headers=headers,
# --> 601                                                   chunked=chunked)
#     602
#     603             # If we're going to release the connection in ``finally:``, then
#
# ~/anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     381             except TypeError:  # Python 2.6 and older, Python 3
#     382                 try:
# --> 383                     httplib_response = conn.getresponse()
#     384                 except Exception as e:
#     385                     # Remove the TypeError from the exception chain in Python 3;
#
# ~/anaconda3/lib/python3.6/http/client.py in getresponse(self)
#    1329         try:
#    1330             try:
# -> 1331                 response.begin()
#    1332             except ConnectionError:
#    1333                 self.close()
#
# ~/anaconda3/lib/python3.6/http/client.py in begin(self)
#     295         # read until we get a non-100 response
#     296         while True:
# --> 297             version, status, reason = self._read_status()
#     298             if status != CONTINUE:
#     299                 break
#
# ~/anaconda3/lib/python3.6/http/client.py in _read_status(self)
#     256
#     257     def _read_status(self):
# --> 258         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     259         if len(line) > _MAXLINE:
#     260             raise LineTooLong("status line")
#
# ~/anaconda3/lib/python3.6/socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# ~/anaconda3/lib/python3.6/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     278     def recv_into(self, *args, **kwargs):
#     279         try:
# --> 280             return self.connection.recv_into(*args, **kwargs)
#     281         except OpenSSL.SSL.SysCallError as e:
#     282             if self.suppress_ragged_eofs and e.args == (-1, 'Unexpected EOF'):
#
# ~/anaconda3/lib/python3.6/site-packages/OpenSSL/SSL.py in recv_into(self, buffer, nbytes, flags)
#    1712             result = _lib.SSL_peek(self._ssl, buf, nbytes)
#    1713         else:
# -> 1714             result = _lib.SSL_read(self._ssl, buf, nbytes)
#    1715         self._raise_ssl_error(self._ssl, result)
#    1716
#
# KeyboardInterrupt:

# %% [markdown]
# The vast majority of failed geocodes are from highways. At the very least, the fuzzy matching above standardized these entries so that future work can be done to either manually geocode them, or to locally store location values for all highways/exits to use for lookups.
#
# A possible strategy here would be to use either OpenStreetMaps, which has this information but is incomplete, or to construct an approximation algorithm using Google Maps nearest road API: i.e., to segment a highway into individual boundaries (the size of which should be experimentally determined), then use the nearest road function restricted to that boundary to geocode a given block number, and then construct a shortest distance line from that road to the highway to approximate a location.

# %% [markdown]
# #### Date Formatting

# %% [markdown]
# For ease of comparison, we format the dates as pd datetime objects.

# %%
datetime_format = "%m/%d/%Y %I:%M:%S %p"
df["Date"] = pd.to_datetime(df["Date"], format = datetime_format)

# %% [markdown]
# #### Missing Community Areas

# %% [markdown]
# With filled in location values, we can now use the city of Chicago's shapefiles to fill in the community area values.

# %%
import geopip

# using geopip, we can create an object that cleanly handles simple point in polygon testing
community_bounds = geopip.GeoPIP("Boundaries - Community Areas (current).geojson")

df.loc[df["Community Area"].isnull() & df["Latitude"].notnull(), "Community Area"] = \
    df[df["Community Area"].isnull() & df["Latitude"].notnull()].apply(lambda x: community_bounds.search(x.Longitude, x.Latitude), axis = 1)

# %% [markdown]
# #### Missing Ward Areas

# %%
current_ward_bounds = geopip.GeoPIP("Boundaries - Wards (2015-).geojson")
old_ward_bounds = geopip.GeoPIP("Boundaries - Wards (2003-2015).geojson")

df.loc[df.Year >= 2015 & df.Latitude.notnull(), "Ward"] = \
    df.loc[df.Year >= 2015 & df.Latitude.notnull()].apply(lambda x: current_ward_bounds.search(x.Longitude, x.Latitude), axis = 1)
    
df.loc[df.Year < 2015 & df.Latitude.notnull(), "Ward"] = \
    df.loc[df.Year < 2015 & df.Latitude.notnull()].apply(lambda x: old_ward_bounds.search(x.Longitude, x.Latitude), axis = 1)
# Out:
#          Case Number                Date                                Block  \
# ID
# 10000092    HY189866 2015-03-18 19:44:00                      047XX W OHIO ST
# 10000094    HY190059 2015-03-18 23:00:00               066XX S MARSHFIELD AVE
# 10000095    HY190052 2015-03-18 22:45:00                044XX S LAKE PARK AVE
# 10000096    HY190054 2015-03-18 22:30:00                 051XX S MICHIGAN AVE
# 10000097    HY189976 2015-03-18 21:00:00                     047XX W ADAMS ST
# 10000098    HY190032 2015-03-18 22:00:00                  049XX S DREXEL BLVD
# 10000099    HY190047 2015-03-18 23:00:00                    070XX S MORGAN ST
# 10000100    HY189988 2015-03-18 21:35:00                  042XX S PRAIRIE AVE
# 10000101    HY190020 2015-03-18 22:09:00                  036XX S WOLCOTT AVE
# 10000104    HY189964 2015-03-18 21:25:00                  097XX S PRAIRIE AVE
# 10000105    HY189984 2015-03-18 21:30:00  130XX S DR MARTIN LUTHER KING JR DR
# 10000108    HY189719 2015-03-15 16:10:00                078XX S VINCENNES AVE
# 10000109    HY189966 2015-03-18 21:14:00                 086XX S EXCHANGE AVE
# 10000110    HY190056 2015-03-18 22:50:00                  014XX S ASHLAND AVE
# 10000111    HY190019 2015-03-18 22:31:00                  051XX W CHICAGO AVE
# 10000112    HY189725 2015-03-18 12:55:00                 077XX S KINGSTON AVE
# 10000114    HY190071 2015-03-18 20:00:00                    024XX W NORTH AVE
# 10000115    HY190036 2015-03-18 21:00:00                  069XX S LOOMIS BLVD
# 10000116    HY190063 2015-03-18 22:56:00                105XX S LAFAYETTE AVE
# 10000117    HY190068 2015-03-18 22:45:00                  087XX S KIMBARK AVE
# 10000118    HY190031 2015-03-18 22:00:00             075XX S STONY ISLAND AVE
# ID
# 10000092  041A                 BATTERY
# 10000094  4625           OTHER OFFENSE
# 10000095  0486                 BATTERY
# 10000096  0460                 BATTERY
# 10000097  031A                 ROBBERY
# 10000098  0460                 BATTERY
# 10000099  0486                 BATTERY
# 10000100  0486                 BATTERY
# 10000101  1811               NARCOTICS
# 10000104  0460                 BATTERY
# 10000105  1320         CRIMINAL DAMAGE
# 10000108  2825           OTHER OFFENSE
# 10000109  143A       WEAPONS VIOLATION
# 10000110  0460                 BATTERY
# 10000111  0860                   THEFT
# 10000112  0610                BURGLARY
# 10000114  0910     MOTOR VEHICLE THEFT
# 10000115  0890                   THEFT
# 10000116  0470  PUBLIC PEACE VIOLATION
# 10000117  0890                   THEFT
# 10000118  0860                   THEFT
# 10000119  0320                 ROBBERY
# 10000120  0430                 BATTERY
# 10000123  141A       WEAPONS VIOLATION
# 10000124  0486                 BATTERY
# 10000126  0486                 BATTERY
# 10000127  0560                 ASSAULT
# 10000129  0460                 BATTERY
# 10000130  041A                 BATTERY
# 10000131  1350       CRIMINAL TRESPASS
# ...        ...                     ...
# 11226096  0281     CRIM SEXUAL ASSAULT
# 11226122  1120      DECEPTIVE PRACTICE
# 11226123  1153      DECEPTIVE PRACTICE
# 11226128  1153      DECEPTIVE PRACTICE
# 11226129  2825           OTHER OFFENSE
# 11226186  0810                   THEFT
# 11226191  5002           OTHER OFFENSE
# 11226019  0860                   THEFT
# 11226042  0860                   THEFT
# 11226066  0890                   THEFT
# 11226067  0890                   THEFT
# 11226069  1152      DECEPTIVE PRACTICE
# 11226110  0620                BURGLARY
# 11226275  1153      DECEPTIVE PRACTICE
# 11226280  1156      DECEPTIVE PRACTICE
# 11226413  1562             SEX OFFENSE
# 11226513  031A                 ROBBERY
# 11226559  1150      DECEPTIVE PRACTICE
# 11226257  0810                   THEFT
# 11226571  1153      DECEPTIVE PRACTICE
# 11226258  1154      DECEPTIVE PRACTICE
# 11226265  0860                   THEFT
# 11226272  0890                   THEFT
# 11226277  0820                   THEFT
# 11226314  0890                   THEFT
# 11226317  1541               OBSCENITY
# 11226343  1153      DECEPTIVE PRACTICE
# 11226368  1152      DECEPTIVE PRACTICE
# 23804     0110                HOMICIDE
# 23805     0110                HOMICIDE
#
#                                       Description  \
# ID
# 10000092                      AGGRAVATED: HANDGUN
# 10000094                         PAROLE VIOLATION
# 10000095                  DOMESTIC BATTERY SIMPLE
# 10000096                                   SIMPLE
# 10000097                           ARMED: HANDGUN
# 10000098                                   SIMPLE
# 10000099                  DOMESTIC BATTERY SIMPLE
# 10000100                  DOMESTIC BATTERY SIMPLE
# 10000101             POSS: CANNABIS 30GMS OR LESS
# 10000104                                   SIMPLE
# 10000105                               TO VEHICLE
# 10000108                  HARASSMENT BY TELEPHONE
# 10000109                 UNLAWFUL POSS OF HANDGUN
# 10000110                                   SIMPLE
# 10000111                             RETAIL THEFT
# 10000112                           FORCIBLE ENTRY
# 10000114                               AUTOMOBILE
# 10000115                            FROM BUILDING
# 10000116                         RECKLESS CONDUCT
# 10000117                            FROM BUILDING
# 10000118                             RETAIL THEFT
# 10000119                    STRONGARM - NO WEAPON
# 10000120            AGGRAVATED: OTHER DANG WEAPON
# 10000123                     UNLAWFUL USE HANDGUN
# 10000124                  DOMESTIC BATTERY SIMPLE
# 10000126                  DOMESTIC BATTERY SIMPLE
# 10000127                                   SIMPLE
# 10000129                                   SIMPLE
# 10000130                      AGGRAVATED: HANDGUN
# 10000131                        TO STATE SUP LAND
# ...                                           ...
# 11226096                           NON-AGGRAVATED
# 11226122                                  FORGERY
# 11226123      FINANCIAL IDENTITY THEFT OVER $ 300
# 11226128      FINANCIAL IDENTITY THEFT OVER $ 300
# 11226129                  HARASSMENT BY TELEPHONE
# 11226186                                OVER $500
# 11226191                    OTHER VEHICLE OFFENSE
# 11226019                             RETAIL THEFT
# 11226042                             RETAIL THEFT
# 11226066                            FROM BUILDING
# 11226067                            FROM BUILDING
# 11226069                    ILLEGAL USE CASH CARD
# 11226110                           UNLAWFUL ENTRY
# 11226275      FINANCIAL IDENTITY THEFT OVER $ 300
# 11226280       ATTEMPT - FINANCIAL IDENTITY THEFT
# 11226413                AGG CRIMINAL SEXUAL ABUSE
# 11226513                           ARMED: HANDGUN
# 11226559                        CREDIT CARD FRAUD
# 11226257                                OVER $500
# 11226571      FINANCIAL IDENTITY THEFT OVER $ 300
# 11226258  FINANCIAL IDENTITY THEFT $300 AND UNDER
# 11226265                             RETAIL THEFT
# 11226272                            FROM BUILDING
# 11226277                           $500 AND UNDER
# 11226314                            FROM BUILDING
# 11226317           SALE/DIST OBSCENE MAT TO MINOR
# 11226343      FINANCIAL IDENTITY THEFT OVER $ 300
# 11226368                    ILLEGAL USE CASH CARD
# 23804                         FIRST DEGREE MURDER
# 23805                         FIRST DEGREE MURDER
#
#                                        Location Description  Arrest  Domestic  \
# ID
# 10000092                                             STREET   False     False
# 10000094                                             STREET    True     False
# 10000095                                          APARTMENT   False      True
# 10000096                                          APARTMENT   False     False
# 10000097                                           SIDEWALK   False     False
# 10000098                                          APARTMENT   False     False
# 10000099                                          APARTMENT   False      True
# 10000100                                          APARTMENT   False      True
# 10000101                                             STREET    True     False
# 10000104                            RESIDENCE PORCH/HALLWAY   False     False
# 10000105                     PARKING LOT/GARAGE(NON.RESID.)   False     False
# 10000108                        CTA GARAGE / OTHER PROPERTY   False      True
# 10000109                             DRIVEWAY - RESIDENTIAL    True     False
# 10000110                                           SIDEWALK   False     False
# 10000111                                        GAS STATION    True     False
# 10000112                                          APARTMENT   False     False
# 10000114                                              OTHER   False     False
# 10000115                                 GROCERY FOOD STORE   False     False
# 10000116                                              ALLEY    True     False
# 10000117                                      BAR OR TAVERN   False     False
# 10000118                                 GROCERY FOOD STORE    True     False
# 10000119                                              OTHER   False     False
# 10000120                                          APARTMENT   False     False
# 10000123                             VEHICLE NON-COMMERCIAL    True     False
# 10000124                                          APARTMENT    True      True
# 10000126                                          APARTMENT    True      True
# 10000127                                          RESIDENCE   False     False
# 10000129                                          APARTMENT   False     False
# 10000130                            RESIDENCE PORCH/HALLWAY   False     False
# 10000131                     PARKING LOT/GARAGE(NON.RESID.)    True     False
# ...                                                     ...     ...       ...
# 11226096                                          APARTMENT   False     False
# 11226122                                          RESIDENCE   False     False
# 11226123                                               BANK   False     False
# 11226128                                               BANK   False     False
# 11226129                                          APARTMENT   False     False
# 11226186                      RESIDENTIAL YARD (FRONT/BACK)   False     False
# 11226191                                             STREET   False     False
# 11226019                                   DEPARTMENT STORE   False     False
# 11226042                                        GAS STATION   False     False
# 11226066                                          RESIDENCE   False     False
# 11226067                                 SMALL RETAIL STORE   False     False
# 11226069                     ATM (AUTOMATIC TELLER MACHINE)   False     False
# 11226110                                          RESIDENCE   False     False
# 11226275                                                NaN   False     False
# 11226280                                          APARTMENT   False     False
# 11226413                                          APARTMENT   False     False
# 11226513  VEHICLE - OTHER RIDE SHARE SERVICE (E.G., UBER...   False     False
# 11226559                                          RESIDENCE   False     False
# 11226257                                           SIDEWALK   False     False
# 11226571                                          RESIDENCE   False     False
# 11226258                                                NaN   False     False
# 11226265                                 SMALL RETAIL STORE   False     False
# 11226272                                 SMALL RETAIL STORE   False     False
# 11226277                                             STREET   False     False
# 11226314                                          APARTMENT   False     False
# 11226317                           SCHOOL, PUBLIC, BUILDING    True     False
# 11226343                                          RESIDENCE   False     False
# 11226368                                          APARTMENT   False     False
# 23804                                                 HOTEL   False     False
# 23805                                                 HOUSE    True      True
#
#           Beat              ...                Ward  Community Area  FBI Code  \
# ID                          ...
# 10000092  1111              ...                28.0            25.0       04B
# 10000094   725              ...                15.0            67.0        26
# 10000095   222              ...                 4.0            39.0       08B
# 10000096   225              ...                 3.0            40.0       08B
# 10000097  1113              ...                28.0            25.0        03
# 10000098   223              ...                 4.0            39.0       08B
# 10000099   733              ...                17.0            68.0       08B
# 10000100   213              ...                 3.0            38.0       08B
# 10000101   912              ...                11.0            59.0        18
# 10000104   511              ...                 6.0            49.0       08B
# 10000105   533              ...                 9.0            54.0        14
# 10000108   623              ...                17.0            69.0        26
# 10000109   423              ...                10.0            46.0        15
# 10000110  1233              ...                 2.0            28.0       08B
# 10000111  1531              ...                37.0            25.0        06
# 10000112   421              ...                 7.0            43.0        05
# 10000114  1423              ...                 1.0            24.0        07
# 10000115   734              ...                17.0            67.0        06
# 10000116   512              ...                34.0            49.0        24
# 10000117   412              ...                 8.0            48.0        06
# 10000118   411              ...                 5.0            43.0        06
# 10000119  2023              ...                48.0            77.0        03
# 10000120   414              ...                 8.0            43.0       04B
# 10000123  1513              ...                29.0            25.0        15
# 10000124  1034              ...                25.0            31.0       08B
# 10000126   232              ...                20.0            40.0       08B
# 10000127  2222              ...                21.0            73.0       08A
# 10000129   621              ...                17.0            71.0       08B
# 10000130   613              ...                21.0            71.0       04B
# 10000131   434              ...                10.0            51.0        26
# ...        ...              ...                 ...             ...       ...
# 11226096  1912              ...                47.0             6.0        02
# 11226122  2523              ...                30.0            21.0        10
# 11226123   634              ...                21.0            44.0        11
# 11226128   634              ...                21.0            44.0        11
# 11226129   133              ...                 3.0            35.0        26
